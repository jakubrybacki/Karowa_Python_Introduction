# %% [markdown]
# ## Zadanie 1: Metody String i konwersje
# Napisz program w którym użytkownik wpisze ciąg cyfr w formacie *string*.
#
# Program powienien kolejno:
# * podzielić łańcuch znaków na pół
# * przekształcić obie części na liczby
# * policzyć sumę obydwu liczba
#
# **Podpowiedź:** Do podzielenia łańcucha wykorzystac możesz operator podwójnego dzielenia (//)

# %%
test = "934123"

# Podzielenie tekstu na pół
czesc1 = test[0: len(test)//2]
czesc2 = test[len(test)//2: len(test)]

# Konwersja do liczb całkowitych 
czesc1 = int(czesc1)
czesc2 = int(czesc2)

# Prosta suma
suma = czesc1 + czesc2
print(suma)

# %% [markdown]
# ## Zadanie 2: Pętle i Krotki
# Bukmacherzy kwotują wyniki zakładów w postaci trzech ilorazów szans, że:
# 1) wygra gospodarz przeciw innym wynikom
# 2) będzie remis
# 3) wygra gość
#
# Za pomocą pętli, przekształć każdą z tych wartości na prawdopodbieństwa takich wydarzęń. Do wykonania takiego obliczenia wykorzystajmy wzór:
#
# $$ prob. = \frac{1}{1 + odds}\ $$
#
# Wynik zwróć w liście albo krotce.

# %%
odds = (3.63, 3.63, 1.98)

probs = [1/(1 + element) for element in odds]
print(probs)

# %% [markdown]
# ## Zadanie 3: Set
# Usuń duplikaty z listy za pomocą odpowiednich konwersji typów struktury.

# %%
miasta = ["m. st. Warszawa", "m. st. Warszawa", "m. st. Warszawa", "Kraków", "Kraków", 
          "Gdańsk", "Gdańsk", "Kraków", "Kraków", "Kraków", "Kraków",
          "Gdańsk", "Gdańsk","Kraków", "Kraków", "Kraków", "Kraków", "Gdańsk"]

unikaty_miast = set(miasta)
print(unikaty_miast)

# %% [markdown]
# ##Zadanie 4: Pętla For
# Wybierz z listy wyłącznie elementy będące tekstami.
#
# **Podpowiedź:** Wykorzystaj funkcję *isinstance*. Program można zapisać w jednej linijce kodu.

# %%
list_chaos = ["wszyscy", 12344, "kłamią", True, 1.9, 2, "Big", None, "Data"]

list_string = [element for element in list_chaos if isinstance(element, str)]
print(list_string)

# %% [markdown]
# ##Zadanie 5: Metody string i słownik
# Wykorzystaj funkcję split, aby rozdzielić fragment tekstu na wyrazy.
#
# Następnie wykorzystaj słownik, aby zliczyć częstotliwość wyrazów wystepujących w tekście.

# %%
inwokacja =  '''Litwo, Ojczyzno moja! ty jesteś jak zdrowie;
Ile cię trzeba cenić, ten tylko się dowie,
Kto cię stracił. Dziś piękność twą w całej ozdobie
Widzę i opisuję, bo tęsknię po tobie.

Panno święta, co Jasnej bronisz Częstochowy
I w Ostrej świecisz Bramie! Ty, co gród zamkowy
Nowogródzki ochraniasz z jego wiernym ludem!
Jak mnie dziecko do zdrowia powróciłaś cudem
(— Gdy od płaczącej matki, pod Twoją opiekę
Ofiarowany martwą podniosłem powiekę;
I zaraz mogłem pieszo, do Twych świątyń progu
Iść za wrócone życie podziękować Bogu —)
Tak nas powrócisz cudem na Ojczyzny łono!...
Tymczasem, przenoś moją duszę utęsknioną
Do tych pagórków leśnych, do tych łąk zielonych,
Szeroko nad błękitnym Niemnem rozciągnionych;
Do tych pól malowanych zbożem rozmaitem,
Wyzłacanych pszenicą, posrebrzanych żytem;
Gdzie bursztynowy świerzop, gryka jak śnieg biała,
Gdzie panieńskim rumieńcem dzięcielina pała,
A wszystko przepasane jakby wstęgą, miedzą
Zieloną, na niej zrzadka ciche grusze siedzą. '''

lista_wyrazow = inwokacja.split()
slownik_wyrazow = {}

for wyraz in lista_wyrazow:
  if wyraz is not slownik_wyrazow:
    slownik_wyrazow[wyraz] = 1
  else:
    slownik_wyrazow[wyraz] += 1

print(slownik_wyrazow)
print(len(slownik_wyrazow))

# %% [markdown]
# #Zadanie 6: Pętle for
# Napisz program, który przybliży całkę z funkcji:
#
# $$ f(x) = x^{3} + 2 $$
#
# w przedziale 0 do 1.
#
# Aby to zrobić policzymy sumy pól kwadratów. Wykonaj pętle *for* która zsumuje wyniki funkcji pomnożony przez wielkość kroku pętli.
#
# Niech pętla:
# * Zaczyna się w 0
# * Kończy się na 1
# * Zmienia się o 0.001.
#
# Matematycznie naszą operacje odzwierciedla taka formuła:
#
# $$  \sum f(x)* \Delta x$$

# %%
calka = 0

for i in range(0, 1000, 1):
  a = i /1000
  calka += (a**3 + 2)*0.001

print(calka)

# %% [markdown]
# Prawdziwy wynik całki można znaleźć [tutaj](https://www.wolframalpha.com/input/?i2d=true&i=Integrate%5BPower%5Bx%2C3%5D%2B2%2C%7Bx%2C0%2C1%7D%5D)

# %% [markdown]
# ## Zadanie 7: Metoda Print
# Wykorzystaj metodę format, aby wyświetlić:
# * wartość liczby pi z 3 miejscami po przecinku
# * binarną, szesnastkową (heskadecymalną) i naukową reprezentację liczby 1023
#
# Pomóc może ci dokumentacja: [link](https://docs.python.org/3/tutorial/inputoutput.html) oraz [artykuł](https://realpython.com/python-formatted-output/)

# %%
pi = 3.1415926
liczba = 1023

# Liczba pi
print("{:.2f}".format(pi))

print()
# Liczba pi
print("Wartość szesnastkowa: {:x}".format(liczba))
print("Notacja naukowa: {:e}".format(liczba))
# Out:
# 3.14
#
# Wartość szesnastkowa: 3ff
# Notacja naukowa: 1.023000e+03
